# %% [markdown]
# <a href="https://colab.research.google.com/github/PRITIKA10/DSBDAL/blob/main/Assignment8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data Analytics I
# Create a Linear Regression Model using Python/R to predict home prices using Boston Housing
# Dataset (https://www.kaggle.com/c/boston-housing). The Boston Housing dataset contains
# information about various houses in Boston through different parameters. There are 506 samples
# and 14 feature variables in this dataset.
# The objective is to predict the value of prices of the house using the given features.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('boston_train.csv')

# %%
df
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 15 columns]

# %%
df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   crim     333 non-null    float64
#  2   zn       333 non-null    float64
#  3   indus    333 non-null    float64
#  4   chas     333 non-null    int64
#  5   nox      333 non-null    float64
#  6   rm       333 non-null    float64
#  7   age      333 non-null    float64
#  8   dis      333 non-null    float64
#  9   rad      333 non-null    int64
#  10  tax      333 non-null    int64
#  11  ptratio  333 non-null    float64
#  12  black    333 non-null    float64
#  13  lstat    333 non-null    float64
#  14  medv     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %%
df.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# std      0.703952   28.133344    1.981123    8.742174  170.841988    2.151821
# min      3.561000    6.000000    1.129600    1.000000  188.000000   12.600000
# 25%      5.884000   45.400000    2.122400    4.000000  279.000000   17.400000
# 50%      6.202000   76.700000    3.092300    5.000000  330.000000   19.000000
# 75%      6.595000   93.800000    5.116700   24.000000  666.000000   20.200000
# max      8.725000  100.000000   10.710300   24.000000  711.000000   21.200000
#
#             black       lstat        medv
# count  333.000000  333.000000  333.000000
# mean   359.466096   12.515435   22.768769
# std     86.584567    7.067781    9.173468
# min      3.500000    1.730000    5.000000
# 25%    376.730000    7.180000   17.400000
# 50%    392.050000   10.970000   21.600000
# 75%    396.240000   16.420000   25.000000
# max    396.900000   37.970000   50.000000

# %%
df.shape
# Out:
# (333, 15)

# %%
df.dtypes
# Out:
# ID           int64
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.isna().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
df.plot.scatter('rm','medv');

# %%
plt.subplots(figsize = (12,8))
sns.heatmap(df.corr());

# %%
df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(331)
sns.distplot(df["crim"],bins=5).set_title("Distribution of CRIM")
plt.subplot(332)
sns.distplot(df["zn"],bins=5).set_title("Distribution of ZN")
plt.subplot(333)
sns.distplot(df["indus"],bins=10).set_title("Distribution of INDUS")
plt.subplot(334)
sns.distplot(df["nox"],bins=20).set_title("Distribution of NOX")
plt.subplot(335)
sns.distplot(df["rm"],bins=20).set_title("Distribution of RM")
plt.subplot(336)
sns.distplot(df["age"],bins=20).set_title("Distribution of AGE")
plt.subplot(337)
sns.distplot(df["dis"],bins=15).set_title("Distribution of DTS")
plt.subplot(338)
sns.distplot(df["tax"],bins=15).set_title("Distribution of TAX")
plt.subplot(339)
sns.distplot(df["rad"],bins=15).set_title("Distribution of RAD")
plt.suptitle("Distribution plot of variables")
plt.show()

# %%
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]

# %%
X.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     18.7  394.63   2.94
# 3     18.7  396.90   5.33
# 4     15.2  395.60  12.43

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    33.4
# 3    36.2
# 4    22.9
# Name: medv, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.20)

# %%
X.shape
# Out:
# (333, 14)

# %%
X_train.shape
# Out:
# (266, 14)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_train)
y_pred
# Out:
# array([33.31079275, 21.68649928, 19.61856229, 29.06344864, 26.91442215,
#        37.46227063, 18.27213951, 31.18293544, 25.27990174, 33.44223829,
#        33.11013269, 24.85319965, 27.4980867 , 26.85246782, 18.38746464,
#        32.24199316,  9.39308214, 14.84008534, 15.3047767 , 31.67469179,
#        28.13293619, 23.79429787, 43.08636283, 25.30646622, 27.99580736,
#        30.62939162, 15.27094287, 27.05272489, 19.07496256, 20.92478221,
#        20.05227265, 19.30541766, 22.77091215, 14.90031194, 22.51695266,
#        25.49407146, 27.23152313, 26.24811503, 27.10700108, 28.42655686,
#        31.10304631, 22.2861832 , 10.02039452, 22.91197745, 28.62913133,
#         2.83502549, 16.57103019, 16.94511222, 26.79095592, 32.61128141,
#        25.06162598, 16.57312228, 30.5149168 , 22.56073074, 19.27903485,
#        22.71077668, 23.31324677, 19.28582615, 26.60738923, 25.00725787,
#        24.52035981, 11.78113133, 25.36005073, 15.45225807, 30.2041431 ,
#        25.71671291, 33.5206627 , 27.03261557, 15.89590981, 20.13848643,
#        27.87246738, 11.8392639 , 34.78270082, 11.38759793, 20.63740109,
#        26.94695374, 18.3164416 , 26.95923009, 20.65423032, 23.36613952,
#        20.03970847, 16.69128835, 24.55197963, 30.64229827, 22.79028247,
#        20.44814206, 18.16956108, 34.74799902, 31.97296253, 24.68869015,
#         7.06164499, 28.46945467, 28.37181643, 13.56869958, 25.0435455 ,
#        16.6207353 , 24.87892596, 23.13595054, 21.06098211, 26.82837149,
#        32.78697983, 21.32572858, 32.13836237,  3.79232673, 25.96688822,
#        24.72451175, 34.03239414, 14.94382159, 41.79811804, 26.18332431,
#        21.67577279, 14.00964281, 33.66542098, 13.05061586, 21.28014654,
#        24.12409408, 31.26376125, 25.71688173,  8.01114931, 33.39111097,
#        20.3984431 , 26.21032743, 17.04997937, 17.70853101, 18.3381063 ,
#        12.47600337, 21.56273825, 28.42884805,  8.18342119, 18.20929728,
#        18.98770912, 16.84961065, 22.19527441, 30.92673656, 22.31854852,
#        35.07484166, 20.69583947, 13.55415778, 26.10120661, 29.44409384,
#        40.55559259, 31.42193094, 17.62814149, 26.30000825, 27.28091262,
#        21.78218558, 34.03582528, 17.74508551, 20.42163627, 30.71535   ,
#        25.99422717, 22.30799845, 15.42178516, 31.03324435, 25.28984542,
#        -2.86489511, 20.97613786, 24.99987254, 23.49645539, 15.67756325,
#        29.81780421, 19.57655091, 20.97957436, 30.09246704, 22.75617897,
#        11.90019597, 34.65652486, 20.58692627, 21.06078283, 23.73102479,
#        24.73806674, 38.57854766, 18.12782422, 19.58444945, 18.28181447,
#        16.32337373, 12.55182554, 20.63475426, 38.47962899, 22.9386229 ,
#        14.86671503, 25.35760521, 16.27819137, 33.32639396, 23.05634169,
#        25.88055096, 38.62625748, 12.14260952, 20.03450394, 28.58940012,
#        23.90276548, 14.87300117, 23.26498119, 19.48780566, 23.5823688 ,
#        28.62640103, 21.59837386, 21.7514346 , 24.33976208, 22.93480285,
#        23.78377249, 22.02079396, 22.53571235, 30.40401337, 17.53651421,
#         2.35673399, 20.84504347, 44.34317131, 18.94042712, 20.40386154,
#        32.13567057, 22.27020411, 16.56823805, 24.20009439, 26.06669231,
#        23.73407613, 25.62964101, 25.35415041, 17.8157812 , 37.78352854,
#        22.48285763, 19.86114814, 18.2156923 , 17.97954639, 10.67863895,
#        21.7838504 , 13.99537123, 14.9533122 , 38.76865239, 25.00052003,
#        40.20965237, 10.22198848, 28.95490733, 20.23130944, 21.32407901,
#        17.3055741 , 25.52829005, 24.48361234, 20.38726205, 22.91341091,
#        19.59848931, 11.55398686, 29.99645844, 40.00268643, 39.35154709,
#        30.58832352, 29.11816891, 27.20296135,  9.48549244, 21.19902372,
#        16.70740756,  5.4149177 , 19.87817665, 21.73033612, 31.24904464,
#        19.76938392, 27.40728554, 16.6634543 , 35.47313466, 14.46156493,
#        20.7561438 , 20.47810287, 13.74427702, 13.10275459, 13.12161635,
#        20.00973047])
